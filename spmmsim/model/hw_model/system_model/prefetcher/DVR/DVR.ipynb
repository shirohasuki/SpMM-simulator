# %%
# Python 实现 Decoupled Vector Runahead (DVR)

class Register:
    def __init__(self):
        self.value = 0
        self.tainted = False  # 表示是否被步长加载污染


class LoadInstruction:
    def __init__(self, pc, stride, target_register):
        self.pc = pc  # 指令地址
        self.stride = stride  # 加载的步长
        self.target_register = target_register  # 目标寄存器


# 全局数据结构
RPT = {}  # 引用预测表（Reference Prediction Table），跟踪步长加载
VRAT = {}  # 矢量寄存器分配表（Vector Register Allocation Table），跟踪矢量化寄存器
VTT = {}  # 矢量污染跟踪器（Vector Taint Tracker），跟踪依赖加载

# 模拟寄存器文件，假设有 32 个寄存器
register_file = {i: Register() for i in range(32)}

# Helper 函数
def is_stride_load(instruction):
    """检查指令是否是步长加载"""
    return instruction.get('is_load') and 'stride' in instruction


def calculate_stride(instruction):
    """计算给定指令的步长"""
    return instruction.get('stride')


def mark_register_tainted(register):
    """标记寄存器为受污染"""
    register_file[register].tainted = True


def dependent_load_found(instruction, instruction_stream):
    """检查当前指令之后是否存在依赖的加载"""
    for next_instruction in instruction_stream:
        if next_instruction.get('source_register') == instruction.get('target_register'):
            return True
    return False


def infer_loop_bounds(instruction, instruction_stream):
    """通过查找后向分支推断循环边界"""
    for next_instruction in instruction_stream:
        if next_instruction.get('is_backward_branch'):
            compare_instruction = find_compare_instruction(next_instruction, instruction_stream)
            if compare_instruction:
                return calculate_loop_iterations(compare_instruction)
    return 128  # 如果未找到循环边界，默认返回 128 次迭代


def find_compare_instruction(branch_instruction, instruction_stream):
    """查找与分支指令关联的比较指令"""
    for instruction in reversed(instruction_stream):
        if instruction.get('is_compare') and instruction.get('branch_target') == branch_instruction.get('pc'):
            return instruction
    return None


def calculate_loop_iterations(compare_instruction):
    """根据比较指令计算循环迭代次数"""
    register_id = compare_instruction.get('target_register')
    loop_bound = register_file[register_id].value - compare_instruction.get('compare_value')
    return max(loop_bound // compare_instruction.get('increment', 1), 0)


# Discovery 模式实现
def discovery_mode(instruction_stream):
    """用于检测步长加载并设置矢量化的 Discovery 模式"""
    for instruction in instruction_stream:
        if is_stride_load(instruction):
            stride = calculate_stride(instruction)
            target_register = instruction.get('target_register')
            
            if instruction.get('pc') not in RPT:
                # 在引用预测表中存储步长加载
                RPT[instruction.get('pc')] = LoadInstruction(instruction.get('pc'), stride, target_register)
            else:
                # 更新内层循环的步长加载
                RPT[instruction.get('pc')] = LoadInstruction(instruction.get('pc'), stride, target_register)

            # 标记目标寄存器为受污染
            mark_register_tainted(target_register)

            # 检查是否有依赖加载
            if dependent_load_found(instruction, instruction_stream):
                VTT[target_register] = True  # 在矢量污染跟踪器中跟踪受污染的寄存器

            # 推断循环边界
            loop_bound = infer_loop_bounds(instruction, instruction_stream)

            # 将信息存储到矢量寄存器分配表中
            VRAT[instruction.get('pc')] = {
                'stride': stride,
                'loop_bound': loop_bound,
                'dependencies': list(VTT.keys())  # 跟踪依赖寄存器
            }

            # 如果找到了足够的未来加载，则退出 Discovery 模式
            if len(VRAT) > 128:
                break
    
    return VRAT


# 矢量化运行前推进执行
def vector_runahead_execution():
    """根据 VRAT 执行矢量化前推进"""
    vectorized_results = []

    # 遍历指令并执行矢量化
    for pc, details in VRAT.items():
        stride = details['stride']
        loop_bound = details['loop_bound']
        dependencies = details['dependencies']

        # 模拟给定循环边界的矢量化执行
        for iteration in range(loop_bound):
            address = pc + iteration * stride
            vectorized_results.append(f"PC: {pc}, Address: {address}, Dependencies: {dependencies}")

    return vectorized_results


# 示例指令流数据
instruction_stream = [
    {'pc': 100, 'is_load': True, 'stride': 4, 'target_register': 1},
    {'pc': 104, 'is_load': True, 'stride': 4, 'target_register': 2, 'source_register': 1},
    {'pc': 108, 'is_load': True, 'stride': 4, 'target_register': 3, 'source_register': 2},
    {'pc': 200, 'is_backward_branch': True, 'branch_target': 100, 'is_compare': True, 'target_register': 1, 'compare_value': 10, 'increment': 1}
]

# 运行 Discovery 模式
VRAT_result = discovery_mode(instruction_stream)

# 执行矢量化前推进
vectorized_execution_result = vector_runahead_execution()

# 打印 VRAT 结果
print("\n矢量寄存器分配表 (VRAT):")
for pc, details in VRAT_result.items():
    print(f"PC: {pc}")
    print(f"  Stride: {details['stride']}")
    print(f"  Loop Bound: {details['loop_bound']}")
    print(f"  Dependencies: {details['dependencies']}\n")

# 打印矢量化前推进执行结果
print("\n矢量化Runahead执行结果:")
for result in vectorized_execution_result:
    print(result)
# Out:
# 矢量寄存器分配表 (VRAT):
# PC: 100
#   Stride: 4
#   Loop Bound: 128
#   Dependencies: [1]
#
# PC: 104
#   Stride: 4
#   Loop Bound: 128
#   Dependencies: [1, 2]
#
# PC: 108
#   Stride: 4
#   Loop Bound: 128
#   Dependencies: [1, 2]
#
#
# 矢量化前推进执行结果:
# PC: 100, Address: 100, Dependencies: [1]
# PC: 100, Address: 104, Dependencies: [1]
# PC: 100, Address: 108, Dependencies: [1]
# PC: 100, Address: 112, Dependencies: [1]
# PC: 100, Address: 116, Dependencies: [1]
# PC: 100, Address: 120, Dependencies: [1]
# PC: 100, Address: 124, Dependencies: [1]
# PC: 100, Address: 128, Dependencies: [1]
# PC: 100, Address: 132, Dependencies: [1]
# PC: 100, Address: 136, Dependencies: [1]
# PC: 100, Address: 140, Dependencies: [1]
# PC: 100, Address: 144, Dependencies: [1]
# PC: 100, Address: 148, Dependencies: [1]
# PC: 100, Address: 152, Dependencies: [1]
# PC: 100, Address: 156, Dependencies: [1]
# PC: 100, Address: 160, Dependencies: [1]
# PC: 100, Address: 164, Dependencies: [1]
# PC: 100, Address: 168, Dependencies: [1]
# PC: 100, Address: 172, Dependencies: [1]
# PC: 100, Address: 176, Dependencies: [1]
# PC: 100, Address: 180, Dependencies: [1]
# PC: 100, Address: 184, Dependencies: [1]
# PC: 100, Address: 188, Dependencies: [1]
# PC: 100, Address: 192, Dependencies: [1]
# PC: 100, Address: 196, Dependencies: [1]
# PC: 100, Address: 200, Dependencies: [1]
# PC: 100, Address: 204, Dependencies: [1]
# PC: 100, Address: 208, Dependencies: [1]
# PC: 100, Address: 212, Dependencies: [1]
# PC: 100, Address: 216, Dependencies: [1]
# PC: 100, Address: 220, Dependencies: [1]
# PC: 100, Address: 224, Dependencies: [1]
# PC: 100, Address: 228, Dependencies: [1]
# PC: 100, Address: 232, Dependencies: [1]
# PC: 100, Address: 236, Dependencies: [1]
# PC: 100, Address: 240, Dependencies: [1]
# PC: 100, Address: 244, Dependencies: [1]
# PC: 100, Address: 248, Dependencies: [1]
# PC: 100, Address: 252, Dependencies: [1]
# PC: 100, Address: 256, Dependencies: [1]
# PC: 100, Address: 260, Dependencies: [1]
# PC: 100, Address: 264, Dependencies: [1]
# PC: 100, Address: 268, Dependencies: [1]
# PC: 100, Address: 272, Dependencies: [1]
# PC: 100, Address: 276, Dependencies: [1]
# PC: 100, Address: 280, Dependencies: [1]
# PC: 100, Address: 284, Dependencies: [1]
# PC: 100, Address: 288, Dependencies: [1]
# PC: 100, Address: 292, Dependencies: [1]
# PC: 100, Address: 296, Dependencies: [1]
# PC: 100, Address: 300, Dependencies: [1]
# PC: 100, Address: 304, Dependencies: [1]
# PC: 100, Address: 308, Dependencies: [1]
# PC: 100, Address: 312, Dependencies: [1]
# PC: 100, Address: 316, Dependencies: [1]
# PC: 100, Address: 320, Dependencies: [1]
# PC: 100, Address: 324, Dependencies: [1]
# PC: 100, Address: 328, Dependencies: [1]
# PC: 100, Address: 332, Dependencies: [1]
# PC: 100, Address: 336, Dependencies: [1]
# PC: 100, Address: 340, Dependencies: [1]
# PC: 100, Address: 344, Dependencies: [1]
# PC: 100, Address: 348, Dependencies: [1]
# PC: 100, Address: 352, Dependencies: [1]
# PC: 100, Address: 356, Dependencies: [1]
# PC: 100, Address: 360, Dependencies: [1]
# PC: 100, Address: 364, Dependencies: [1]
# PC: 100, Address: 368, Dependencies: [1]
# PC: 100, Address: 372, Dependencies: [1]
# PC: 100, Address: 376, Dependencies: [1]
# PC: 100, Address: 380, Dependencies: [1]
# PC: 100, Address: 384, Dependencies: [1]
# PC: 100, Address: 388, Dependencies: [1]
# PC: 100, Address: 392, Dependencies: [1]
# PC: 100, Address: 396, Dependencies: [1]
# PC: 100, Address: 400, Dependencies: [1]
# PC: 100, Address: 404, Dependencies: [1]
# PC: 100, Address: 408, Dependencies: [1]
# PC: 100, Address: 412, Dependencies: [1]
# PC: 100, Address: 416, Dependencies: [1]
# PC: 100, Address: 420, Dependencies: [1]
# PC: 100, Address: 424, Dependencies: [1]
# PC: 100, Address: 428, Dependencies: [1]
# PC: 100, Address: 432, Dependencies: [1]
# PC: 100, Address: 436, Dependencies: [1]
# PC: 100, Address: 440, Dependencies: [1]
# PC: 100, Address: 444, Dependencies: [1]
# PC: 100, Address: 448, Dependencies: [1]
# PC: 100, Address: 452, Dependencies: [1]
# PC: 100, Address: 456, Dependencies: [1]
# PC: 100, Address: 460, Dependencies: [1]
# PC: 100, Address: 464, Dependencies: [1]
# PC: 100, Address: 468, Dependencies: [1]
# PC: 100, Address: 472, Dependencies: [1]
# PC: 100, Address: 476, Dependencies: [1]
# PC: 100, Address: 480, Dependencies: [1]
# PC: 100, Address: 484, Dependencies: [1]
# PC: 100, Address: 488, Dependencies: [1]
# PC: 100, Address: 492, Dependencies: [1]
# PC: 100, Address: 496, Dependencies: [1]
# PC: 100, Address: 500, Dependencies: [1]
# PC: 100, Address: 504, Dependencies: [1]
# PC: 100, Address: 508, Dependencies: [1]
# PC: 100, Address: 512, Dependencies: [1]
# PC: 100, Address: 516, Dependencies: [1]
# PC: 100, Address: 520, Dependencies: [1]
# PC: 100, Address: 524, Dependencies: [1]
# PC: 100, Address: 528, Dependencies: [1]
# PC: 100, Address: 532, Dependencies: [1]
# PC: 100, Address: 536, Dependencies: [1]
# PC: 100, Address: 540, Dependencies: [1]
# PC: 100, Address: 544, Dependencies: [1]
# PC: 100, Address: 548, Dependencies: [1]
# PC: 100, Address: 552, Dependencies: [1]
# PC: 100, Address: 556, Dependencies: [1]
# PC: 100, Address: 560, Dependencies: [1]
# PC: 100, Address: 564, Dependencies: [1]
# PC: 100, Address: 568, Dependencies: [1]
# PC: 100, Address: 572, Dependencies: [1]
# PC: 100, Address: 576, Dependencies: [1]
# PC: 100, Address: 580, Dependencies: [1]
# PC: 100, Address: 584, Dependencies: [1]
# PC: 100, Address: 588, Dependencies: [1]
# PC: 100, Address: 592, Dependencies: [1]
# PC: 100, Address: 596, Dependencies: [1]
# PC: 100, Address: 600, Dependencies: [1]
# PC: 100, Address: 604, Dependencies: [1]
# PC: 100, Address: 608, Dependencies: [1]
# PC: 104, Address: 104, Dependencies: [1, 2]
# PC: 104, Address: 108, Dependencies: [1, 2]
# PC: 104, Address: 112, Dependencies: [1, 2]
# PC: 104, Address: 116, Dependencies: [1, 2]
# PC: 104, Address: 120, Dependencies: [1, 2]
# PC: 104, Address: 124, Dependencies: [1, 2]
# PC: 104, Address: 128, Dependencies: [1, 2]
# PC: 104, Address: 132, Dependencies: [1, 2]
# PC: 104, Address: 136, Dependencies: [1, 2]
# PC: 104, Address: 140, Dependencies: [1, 2]
# PC: 104, Address: 144, Dependencies: [1, 2]
# PC: 104, Address: 148, Dependencies: [1, 2]
# PC: 104, Address: 152, Dependencies: [1, 2]
# PC: 104, Address: 156, Dependencies: [1, 2]
# PC: 104, Address: 160, Dependencies: [1, 2]
# PC: 104, Address: 164, Dependencies: [1, 2]
# PC: 104, Address: 168, Dependencies: [1, 2]
# PC: 104, Address: 172, Dependencies: [1, 2]
# PC: 104, Address: 176, Dependencies: [1, 2]
# PC: 104, Address: 180, Dependencies: [1, 2]
# PC: 104, Address: 184, Dependencies: [1, 2]
# PC: 104, Address: 188, Dependencies: [1, 2]
# PC: 104, Address: 192, Dependencies: [1, 2]
# PC: 104, Address: 196, Dependencies: [1, 2]
# PC: 104, Address: 200, Dependencies: [1, 2]
# PC: 104, Address: 204, Dependencies: [1, 2]
# PC: 104, Address: 208, Dependencies: [1, 2]
# PC: 104, Address: 212, Dependencies: [1, 2]
# PC: 104, Address: 216, Dependencies: [1, 2]
# PC: 104, Address: 220, Dependencies: [1, 2]
# PC: 104, Address: 224, Dependencies: [1, 2]
# PC: 104, Address: 228, Dependencies: [1, 2]
# PC: 104, Address: 232, Dependencies: [1, 2]
# PC: 104, Address: 236, Dependencies: [1, 2]
# PC: 104, Address: 240, Dependencies: [1, 2]
# PC: 104, Address: 244, Dependencies: [1, 2]
# PC: 104, Address: 248, Dependencies: [1, 2]
# PC: 104, Address: 252, Dependencies: [1, 2]
# PC: 104, Address: 256, Dependencies: [1, 2]
# PC: 104, Address: 260, Dependencies: [1, 2]
# PC: 104, Address: 264, Dependencies: [1, 2]
# PC: 104, Address: 268, Dependencies: [1, 2]
# PC: 104, Address: 272, Dependencies: [1, 2]
# PC: 104, Address: 276, Dependencies: [1, 2]
# PC: 104, Address: 280, Dependencies: [1, 2]
# PC: 104, Address: 284, Dependencies: [1, 2]
# PC: 104, Address: 288, Dependencies: [1, 2]
# PC: 104, Address: 292, Dependencies: [1, 2]
# PC: 104, Address: 296, Dependencies: [1, 2]
# PC: 104, Address: 300, Dependencies: [1, 2]
# PC: 104, Address: 304, Dependencies: [1, 2]
# PC: 104, Address: 308, Dependencies: [1, 2]
# PC: 104, Address: 312, Dependencies: [1, 2]
# PC: 104, Address: 316, Dependencies: [1, 2]
# PC: 104, Address: 320, Dependencies: [1, 2]
# PC: 104, Address: 324, Dependencies: [1, 2]
# PC: 104, Address: 328, Dependencies: [1, 2]
# PC: 104, Address: 332, Dependencies: [1, 2]
# PC: 104, Address: 336, Dependencies: [1, 2]
# PC: 104, Address: 340, Dependencies: [1, 2]
# PC: 104, Address: 344, Dependencies: [1, 2]
# PC: 104, Address: 348, Dependencies: [1, 2]
# PC: 104, Address: 352, Dependencies: [1, 2]
# PC: 104, Address: 356, Dependencies: [1, 2]
# PC: 104, Address: 360, Dependencies: [1, 2]
# PC: 104, Address: 364, Dependencies: [1, 2]
# PC: 104, Address: 368, Dependencies: [1, 2]
# PC: 104, Address: 372, Dependencies: [1, 2]
# PC: 104, Address: 376, Dependencies: [1, 2]
# PC: 104, Address: 380, Dependencies: [1, 2]
# PC: 104, Address: 384, Dependencies: [1, 2]
# PC: 104, Address: 388, Dependencies: [1, 2]
# PC: 104, Address: 392, Dependencies: [1, 2]
# PC: 104, Address: 396, Dependencies: [1, 2]
# PC: 104, Address: 400, Dependencies: [1, 2]
# PC: 104, Address: 404, Dependencies: [1, 2]
# PC: 104, Address: 408, Dependencies: [1, 2]
# PC: 104, Address: 412, Dependencies: [1, 2]
# PC: 104, Address: 416, Dependencies: [1, 2]
# PC: 104, Address: 420, Dependencies: [1, 2]
# PC: 104, Address: 424, Dependencies: [1, 2]
# PC: 104, Address: 428, Dependencies: [1, 2]
# PC: 104, Address: 432, Dependencies: [1, 2]
# PC: 104, Address: 436, Dependencies: [1, 2]
# PC: 104, Address: 440, Dependencies: [1, 2]
# PC: 104, Address: 444, Dependencies: [1, 2]
# PC: 104, Address: 448, Dependencies: [1, 2]
# PC: 104, Address: 452, Dependencies: [1, 2]
# PC: 104, Address: 456, Dependencies: [1, 2]
# PC: 104, Address: 460, Dependencies: [1, 2]
# PC: 104, Address: 464, Dependencies: [1, 2]
# PC: 104, Address: 468, Dependencies: [1, 2]
# PC: 104, Address: 472, Dependencies: [1, 2]
# PC: 104, Address: 476, Dependencies: [1, 2]
# PC: 104, Address: 480, Dependencies: [1, 2]
# PC: 104, Address: 484, Dependencies: [1, 2]
# PC: 104, Address: 488, Dependencies: [1, 2]
# PC: 104, Address: 492, Dependencies: [1, 2]
# PC: 104, Address: 496, Dependencies: [1, 2]
# PC: 104, Address: 500, Dependencies: [1, 2]
# PC: 104, Address: 504, Dependencies: [1, 2]
# PC: 104, Address: 508, Dependencies: [1, 2]
# PC: 104, Address: 512, Dependencies: [1, 2]
# PC: 104, Address: 516, Dependencies: [1, 2]
# PC: 104, Address: 520, Dependencies: [1, 2]
# PC: 104, Address: 524, Dependencies: [1, 2]
# PC: 104, Address: 528, Dependencies: [1, 2]
# PC: 104, Address: 532, Dependencies: [1, 2]
# PC: 104, Address: 536, Dependencies: [1, 2]
# PC: 104, Address: 540, Dependencies: [1, 2]
# PC: 104, Address: 544, Dependencies: [1, 2]
# PC: 104, Address: 548, Dependencies: [1, 2]
# PC: 104, Address: 552, Dependencies: [1, 2]
# PC: 104, Address: 556, Dependencies: [1, 2]
# PC: 104, Address: 560, Dependencies: [1, 2]
# PC: 104, Address: 564, Dependencies: [1, 2]
# PC: 104, Address: 568, Dependencies: [1, 2]
# PC: 104, Address: 572, Dependencies: [1, 2]
# PC: 104, Address: 576, Dependencies: [1, 2]
# PC: 104, Address: 580, Dependencies: [1, 2]
# PC: 104, Address: 584, Dependencies: [1, 2]
# PC: 104, Address: 588, Dependencies: [1, 2]
# PC: 104, Address: 592, Dependencies: [1, 2]
# PC: 104, Address: 596, Dependencies: [1, 2]
# PC: 104, Address: 600, Dependencies: [1, 2]
# PC: 104, Address: 604, Dependencies: [1, 2]
# PC: 104, Address: 608, Dependencies: [1, 2]
# PC: 104, Address: 612, Dependencies: [1, 2]
# PC: 108, Address: 108, Dependencies: [1, 2]
# PC: 108, Address: 112, Dependencies: [1, 2]
# PC: 108, Address: 116, Dependencies: [1, 2]
# PC: 108, Address: 120, Dependencies: [1, 2]
# PC: 108, Address: 124, Dependencies: [1, 2]
# PC: 108, Address: 128, Dependencies: [1, 2]
# PC: 108, Address: 132, Dependencies: [1, 2]
# PC: 108, Address: 136, Dependencies: [1, 2]
# PC: 108, Address: 140, Dependencies: [1, 2]
# PC: 108, Address: 144, Dependencies: [1, 2]
# PC: 108, Address: 148, Dependencies: [1, 2]
# PC: 108, Address: 152, Dependencies: [1, 2]
# PC: 108, Address: 156, Dependencies: [1, 2]
# PC: 108, Address: 160, Dependencies: [1, 2]
# PC: 108, Address: 164, Dependencies: [1, 2]
# PC: 108, Address: 168, Dependencies: [1, 2]
# PC: 108, Address: 172, Dependencies: [1, 2]
# PC: 108, Address: 176, Dependencies: [1, 2]
# PC: 108, Address: 180, Dependencies: [1, 2]
# PC: 108, Address: 184, Dependencies: [1, 2]
# PC: 108, Address: 188, Dependencies: [1, 2]
# PC: 108, Address: 192, Dependencies: [1, 2]
# PC: 108, Address: 196, Dependencies: [1, 2]
# PC: 108, Address: 200, Dependencies: [1, 2]
# PC: 108, Address: 204, Dependencies: [1, 2]
# PC: 108, Address: 208, Dependencies: [1, 2]
# PC: 108, Address: 212, Dependencies: [1, 2]
# PC: 108, Address: 216, Dependencies: [1, 2]
# PC: 108, Address: 220, Dependencies: [1, 2]
# PC: 108, Address: 224, Dependencies: [1, 2]
# PC: 108, Address: 228, Dependencies: [1, 2]
# PC: 108, Address: 232, Dependencies: [1, 2]
# PC: 108, Address: 236, Dependencies: [1, 2]
# PC: 108, Address: 240, Dependencies: [1, 2]
# PC: 108, Address: 244, Dependencies: [1, 2]
# PC: 108, Address: 248, Dependencies: [1, 2]
# PC: 108, Address: 252, Dependencies: [1, 2]
# PC: 108, Address: 256, Dependencies: [1, 2]
# PC: 108, Address: 260, Dependencies: [1, 2]
# PC: 108, Address: 264, Dependencies: [1, 2]
# PC: 108, Address: 268, Dependencies: [1, 2]
# PC: 108, Address: 272, Dependencies: [1, 2]
# PC: 108, Address: 276, Dependencies: [1, 2]
# PC: 108, Address: 280, Dependencies: [1, 2]
# PC: 108, Address: 284, Dependencies: [1, 2]
# PC: 108, Address: 288, Dependencies: [1, 2]
# PC: 108, Address: 292, Dependencies: [1, 2]
# PC: 108, Address: 296, Dependencies: [1, 2]
# PC: 108, Address: 300, Dependencies: [1, 2]
# PC: 108, Address: 304, Dependencies: [1, 2]
# PC: 108, Address: 308, Dependencies: [1, 2]
# PC: 108, Address: 312, Dependencies: [1, 2]
# PC: 108, Address: 316, Dependencies: [1, 2]
# PC: 108, Address: 320, Dependencies: [1, 2]
# PC: 108, Address: 324, Dependencies: [1, 2]
# PC: 108, Address: 328, Dependencies: [1, 2]
# PC: 108, Address: 332, Dependencies: [1, 2]
# PC: 108, Address: 336, Dependencies: [1, 2]
# PC: 108, Address: 340, Dependencies: [1, 2]
# PC: 108, Address: 344, Dependencies: [1, 2]
# PC: 108, Address: 348, Dependencies: [1, 2]
# PC: 108, Address: 352, Dependencies: [1, 2]
# PC: 108, Address: 356, Dependencies: [1, 2]
# PC: 108, Address: 360, Dependencies: [1, 2]
# PC: 108, Address: 364, Dependencies: [1, 2]
# PC: 108, Address: 368, Dependencies: [1, 2]
# PC: 108, Address: 372, Dependencies: [1, 2]
# PC: 108, Address: 376, Dependencies: [1, 2]
# PC: 108, Address: 380, Dependencies: [1, 2]
# PC: 108, Address: 384, Dependencies: [1, 2]
# PC: 108, Address: 388, Dependencies: [1, 2]
# PC: 108, Address: 392, Dependencies: [1, 2]
# PC: 108, Address: 396, Dependencies: [1, 2]
# PC: 108, Address: 400, Dependencies: [1, 2]
# PC: 108, Address: 404, Dependencies: [1, 2]
# PC: 108, Address: 408, Dependencies: [1, 2]
# PC: 108, Address: 412, Dependencies: [1, 2]
# PC: 108, Address: 416, Dependencies: [1, 2]
# PC: 108, Address: 420, Dependencies: [1, 2]
# PC: 108, Address: 424, Dependencies: [1, 2]
# PC: 108, Address: 428, Dependencies: [1, 2]
# PC: 108, Address: 432, Dependencies: [1, 2]
# PC: 108, Address: 436, Dependencies: [1, 2]
# PC: 108, Address: 440, Dependencies: [1, 2]
# PC: 108, Address: 444, Dependencies: [1, 2]
# PC: 108, Address: 448, Dependencies: [1, 2]
# PC: 108, Address: 452, Dependencies: [1, 2]
# PC: 108, Address: 456, Dependencies: [1, 2]
# PC: 108, Address: 460, Dependencies: [1, 2]
# PC: 108, Address: 464, Dependencies: [1, 2]
# PC: 108, Address: 468, Dependencies: [1, 2]
# PC: 108, Address: 472, Dependencies: [1, 2]
# PC: 108, Address: 476, Dependencies: [1, 2]
# PC: 108, Address: 480, Dependencies: [1, 2]
# PC: 108, Address: 484, Dependencies: [1, 2]
# PC: 108, Address: 488, Dependencies: [1, 2]
# PC: 108, Address: 492, Dependencies: [1, 2]
# PC: 108, Address: 496, Dependencies: [1, 2]
# PC: 108, Address: 500, Dependencies: [1, 2]
# PC: 108, Address: 504, Dependencies: [1, 2]
# PC: 108, Address: 508, Dependencies: [1, 2]
# PC: 108, Address: 512, Dependencies: [1, 2]
# PC: 108, Address: 516, Dependencies: [1, 2]
# PC: 108, Address: 520, Dependencies: [1, 2]
# PC: 108, Address: 524, Dependencies: [1, 2]
# PC: 108, Address: 528, Dependencies: [1, 2]
# PC: 108, Address: 532, Dependencies: [1, 2]
# PC: 108, Address: 536, Dependencies: [1, 2]
# PC: 108, Address: 540, Dependencies: [1, 2]
# PC: 108, Address: 544, Dependencies: [1, 2]
# PC: 108, Address: 548, Dependencies: [1, 2]
# PC: 108, Address: 552, Dependencies: [1, 2]
# PC: 108, Address: 556, Dependencies: [1, 2]
# PC: 108, Address: 560, Dependencies: [1, 2]
# PC: 108, Address: 564, Dependencies: [1, 2]
# PC: 108, Address: 568, Dependencies: [1, 2]
# PC: 108, Address: 572, Dependencies: [1, 2]
# PC: 108, Address: 576, Dependencies: [1, 2]
# PC: 108, Address: 580, Dependencies: [1, 2]
# PC: 108, Address: 584, Dependencies: [1, 2]
# PC: 108, Address: 588, Dependencies: [1, 2]
# PC: 108, Address: 592, Dependencies: [1, 2]
# PC: 108, Address: 596, Dependencies: [1, 2]
# PC: 108, Address: 600, Dependencies: [1, 2]
# PC: 108, Address: 604, Dependencies: [1, 2]
# PC: 108, Address: 608, Dependencies: [1, 2]
# PC: 108, Address: 612, Dependencies: [1, 2]
# PC: 108, Address: 616, Dependencies: [1, 2]
